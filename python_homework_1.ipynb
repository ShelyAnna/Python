# %%
import requests, json, urllib.parse

# %%
base_url = 'https://itunes.apple.com/search'

artist = 'Arctic Monkeys'

params = {
    'term': artist,
    'limit': 200,
    'media': 'music',
    'entity': 'song',
    'attribute': 'artistTerm'
}

response = requests.get(f"{base_url}?{urllib.parse.urlencode(params)}")

data = json.loads(response.text)
data = data['results']

# %%
data = map(lambda x: {
    'artistName': x['artistName'],
    'kind' : x['kind'],
    'artistId': x['artistId'],
    'collectionId': x['collectionId'],
    'trackId': x['trackId'],
    'artistName': x['artistName'],
    'collectionName': x['collectionName'],
    'trackName': x['trackName'],
    'trackPrice': x['trackPrice'],
    'releaseDate': x['releaseDate'],
    'trackCount': x['trackCount'],
    'trackTimeMillis': x['trackTimeMillis'],
    'primaryGenreName': x['primaryGenreName']
}, data)
data = list(data)

# %%
def convert_millis(millis: int) -> str:
    total_seconds = millis // 1000
    seconds = total_seconds % 60
    minutes = (total_seconds // 60) % 60
    hours = (total_seconds // (60 * 60))
    return f"{hours}:Hours,{minutes}:Minutes,{seconds}:Seconds"

# %%
def get_info_songs(data):
    result = {}
    result['Count of tracks'] = len(data)
    result['Most popular genre'] = statistics.mode(list(map(lambda x: x['primaryGenreName'].lower(), data)))
    result['Count of collection'] = len(set(map(lambda x: x['collectionId'], data)))

    result['Total track time'] = sum(list(map(lambda x: x['trackTimeMillis'], data)))
    result['Average track time'] = convert_millis(result['Total track time'] / result['Count of tracks'])
    result['Median track time'] = convert_millis(statistics.median(map(lambda x: x['trackTimeMillis'], data)))
    result['Total track time'] = convert_millis(result['Total track time'])

    result['Longest song time'] = max(map(lambda x: x['trackTimeMillis'], data))
    result['Longest song name'] = next(filter(lambda x: x.get('trackTimeMillis') == result['Longest song time'], data), None)['trackName']
    result['Longest song time'] = convert_millis(result['Longest song time'])

    result['Shortest song time'] = min(map(lambda x: x['trackTimeMillis'], data))
    result['Shortest song name'] = next(filter(lambda x: x.get('trackTimeMillis') == result['Shortest song time'], data), None)['trackName']
    result['Shortest song time'] = convert_millis(result['Shortest song time'])

    result['Total cost of songs'] = sum(list(map(lambda x: x['trackPrice'], data)))
    result['Average cost of songs'] = result['Total cost of songs'] / result['Count of tracks']
    result['Median cost of songs'] = statistics.median(map(lambda x: x['trackPrice'], data))

    result['Most expensive song cost'] = max(map(lambda x: x['trackPrice'], data))
    result['Most expensive song name'] = next(filter(lambda x: x.get('trackPrice') == result['Most expensive song cost'], data), None)['trackName']

    result['Сheapest song cost'] = min(map(lambda x: x['trackPrice'], data))
    result['Сheapest song name'] = next(filter(lambda x: x.get('trackPrice') == result['Сheapest song cost'], data), None)['trackName']
    return result

# %%
import statistics

info = get_info_songs(data)
info['Artist'] = artist
info
# Out:
# {'Count of tracks': 192,
#  'Most popular genre': 'alternative',
#  'Count of collection': 37,
#  'Total track time': '11:Hours,7:Minutes,59:Seconds',
#  'Average track time': '0.0:Hours,3.0:Minutes,28.0:Seconds',
#  'Median track time': '0.0:Hours,3.0:Minutes,22.0:Seconds',
#  'Longest song time': '0:Hours,6:Minutes,11:Seconds',
#  'Longest song name': 'R U Mine?',
#  'Shortest song time': '0:Hours,1:Minutes,20:Seconds',
#  'Shortest song name': "Stickin' to the Floor",
#  'Total cost of songs': 225.5899999999999,
#  'Average cost of songs': 1.174947916666666,
#  'Median cost of songs': 1.29,
#  'Most expensive song cost': 1.29,
#  'Most expensive song name': 'Do I Wanna Know?',
#  'Сheapest song cost': -1.0,
#  'Сheapest song name': 'Do I Wanna Know?',
#  'Artist': 'Arctic Monkeys'}

# %%
from itertools import groupby

collection_id_extractor = lambda x: x['collectionId']
album_groups = {}
album_names = {}

sorted_by_album = sorted(data, key=collection_id_extractor)
for album_id, songs in groupby(sorted_by_album, key=collection_id_extractor):
    songs = list(songs)
    album_groups[album_id] = songs 
    album_names[album_id] = songs[0]['collectionName']

info_album_list = []
for album_id, songs in album_groups.items():
    info_album = get_info_songs(songs)
    info_album['Album name'] = album_names[album_id]
    info_album['Release date album'] = album_groups[album_id][0]['releaseDate']
    info_album_list.append(info_album)
    
info_album_list
# Out:
# [{'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,10:Minutes,11:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,32.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,44.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,22:Seconds',
#   'Longest song name': 'When the Sun Goes Down',
#   'Shortest song time': '0:Hours,1:Minutes,20:Seconds',
#   'Shortest song name': "Stickin' to the Floor",
#   'Total cost of songs': 3.96,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'When the Sun Goes Down',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'When the Sun Goes Down',
#   'Album name': 'When the Sun Goes Down - EP',
#   'Release date album': '2006-01-16T12:00:00Z'},
#  {'Count of tracks': 13,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,41:Minutes,26:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,11.0:Seconds',
#   'Median track time': '0:Hours,2:Minutes,57:Seconds',
#   'Longest song time': '0:Hours,5:Minutes,31:Seconds',
#   'Longest song name': 'A Certain Romance',
#   'Shortest song time': '0:Hours,2:Minutes,12:Seconds',
#   'Shortest song name': "You Probably Couldn't See for the Lights but You Were Staring Straight at Me",
#   'Total cost of songs': 16.769999999999996,
#   'Average cost of songs': 1.2899999999999996,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Mardy Bum',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Mardy Bum',
#   'Album name': "Whatever People Say I Am, That's What I'm Not",
#   'Release date album': '2006-01-23T08:00:00Z'},
#  {'Count of tracks': 5,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,18:Minutes,54:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,46.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,22:Seconds',
#   'Longest song time': '0:Hours,5:Minutes,36:Seconds',
#   'Longest song name': 'Who the Fuck Are Arctic Monkeys?',
#   'Shortest song time': '0:Hours,2:Minutes,56:Seconds',
#   'Shortest song name': 'Cigarette Smoker Fiona',
#   'Total cost of songs': 6.45,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Cigarette Smoker Fiona',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Cigarette Smoker Fiona',
#   'Album name': 'Who the F*** Are Arctic Monkeys? - EP',
#   'Release date album': '2006-04-24T12:00:00Z'},
#  {'Count of tracks': 3,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,9:Minutes,35:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,11.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,1:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,52:Seconds',
#   'Longest song name': 'Leave Before the Lights Come On',
#   'Shortest song time': '0:Hours,2:Minutes,41:Seconds',
#   'Shortest song name': "Baby I'm Yours",
#   'Total cost of songs': 2.9699999999999998,
#   'Average cost of songs': 0.9899999999999999,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Leave Before the Lights Come On',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Leave Before the Lights Come On',
#   'Album name': 'Leave Before the Lights Come On - EP',
#   'Release date album': '2006-08-14T07:00:00Z'},
#  {'Count of tracks': 3,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,9:Minutes,21:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,7.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,2:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,27:Seconds',
#   'Longest song name': 'Temptation Greets You Like Your Naughty Friend',
#   'Shortest song time': '0:Hours,2:Minutes,50:Seconds',
#   'Shortest song name': 'Brianstorm',
#   'Total cost of songs': 2.9699999999999998,
#   'Average cost of songs': 0.9899999999999999,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Temptation Greets You Like Your Naughty Friend',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Temptation Greets You Like Your Naughty Friend',
#   'Album name': 'Brianstorm - Single',
#   'Release date album': '2007-04-16T12:00:00Z'},
#  {'Count of tracks': 12,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,37:Minutes,23:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,6.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,57.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,34:Seconds',
#   'Longest song name': 'If You Were There, Beware',
#   'Shortest song time': '0:Hours,2:Minutes,14:Seconds',
#   'Shortest song name': 'D Is for Dangerous',
#   'Total cost of songs': 13.38,
#   'Average cost of songs': 1.115,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Fluorescent Adolescent',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Do Me a Favour',
#   'Album name': 'Favourite Worst Nightmare',
#   'Release date album': '2007-04-20T07:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'rock',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,7:Minutes,21:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,40.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,40.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,58:Seconds',
#   'Longest song name': 'Matador',
#   'Shortest song time': '0:Hours,2:Minutes,22:Seconds',
#   'Shortest song name': 'Da Frame 2R',
#   'Total cost of songs': 1.98,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Da Frame 2R',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Da Frame 2R',
#   'Album name': 'Da Frame 2R / Matador - Single',
#   'Release date album': '2007-06-18T07:00:00Z'},
#  {'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,11:Minutes,57:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,59.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,59.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,3:Seconds',
#   'Longest song name': 'Fluorescent Adolescent',
#   'Shortest song time': '0:Hours,2:Minutes,53:Seconds',
#   'Shortest song name': 'Plastic Tramp',
#   'Total cost of songs': 3.96,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Plastic Tramp',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Plastic Tramp',
#   'Album name': 'Fluorescent Adolescent - EP',
#   'Release date album': '2007-07-08T07:00:00Z'},
#  {'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,11:Minutes,57:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,59.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,59.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,3:Seconds',
#   'Longest song name': 'Fluorescent Adolescent',
#   'Shortest song time': '0:Hours,2:Minutes,53:Seconds',
#   'Shortest song name': 'Plastic Tramp',
#   'Total cost of songs': 3.96,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Fluorescent Adolescent',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Fluorescent Adolescent',
#   'Album name': 'Fluorescent Adolescent - EP',
#   'Release date album': '2007-04-18T07:00:00Z'},
#  {'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,10:Minutes,4:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,31.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,30.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,19:Seconds',
#   'Longest song name': 'The Death Ramps',
#   'Shortest song time': '0:Hours,1:Minutes,44:Seconds',
#   'Shortest song name': 'Nettles',
#   'Total cost of songs': 3.96,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Bad Woman',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Bad Woman',
#   'Album name': 'Teddy Picker - EP',
#   'Release date album': '2007-12-02T08:00:00Z'},
#  {'Count of tracks': 3,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,10:Minutes,37:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,32.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,40:Seconds',
#   'Longest song name': 'Chun Li Flying Bird Kick',
#   'Shortest song time': '0:Hours,2:Minutes,56:Seconds',
#   'Shortest song name': 'I Bet You Look Good On the Dancefloor',
#   'Total cost of songs': 3.27,
#   'Average cost of songs': 1.09,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'I Bet You Look Good On the Dancefloor',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Bigger Boys and Stolen Sweethearts',
#   'Album name': 'I Bet You Look Good On the Dancefloor - EP',
#   'Release date album': '2005-10-17T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,3:Minutes,42:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,42.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,42:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,42:Seconds',
#   'Longest song name': 'Crying Lightning',
#   'Shortest song time': '0:Hours,3:Minutes,42:Seconds',
#   'Shortest song name': 'Crying Lightning',
#   'Total cost of songs': 0.99,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Crying Lightning',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Crying Lightning',
#   'Album name': 'Crying Lightning - Single',
#   'Release date album': '2009-07-06T12:00:00Z'},
#  {'Count of tracks': 3,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,9:Minutes,34:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,11.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,44:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,19:Seconds',
#   'Longest song name': 'Red Right Hand',
#   'Shortest song time': '0:Hours,1:Minutes,29:Seconds',
#   'Shortest song name': "I Haven't Got My Strange",
#   'Total cost of songs': 2.9699999999999998,
#   'Average cost of songs': 0.9899999999999999,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Red Right Hand',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Red Right Hand',
#   'Album name': 'Crying Lightning - EP',
#   'Release date album': '2009-07-06T12:00:00Z'},
#  {'Count of tracks': 10,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,39:Minutes,19:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,55.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,41.0:Seconds',
#   'Longest song time': '0:Hours,5:Minutes,43:Seconds',
#   'Longest song name': "The Jeweller's Hands",
#   'Shortest song time': '0:Hours,3:Minutes,17:Seconds',
#   'Shortest song name': 'Cornerstone',
#   'Total cost of songs': 9.9,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Crying Lightning',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Crying Lightning',
#   'Album name': 'Humbug',
#   'Release date album': '2009-07-06T12:00:00Z'},
#  {'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,12:Minutes,19:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,4.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,23.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,28:Seconds',
#   'Longest song name': 'Catapult',
#   'Shortest song time': '0:Hours,2:Minutes,4:Seconds',
#   'Shortest song name': 'Sketchead',
#   'Total cost of songs': 3.96,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Fright Lined Dining Room',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Fright Lined Dining Room',
#   'Album name': 'Cornerstone - EP',
#   'Release date album': '2009-11-16T12:00:00Z'},
#  {'Count of tracks': 4,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,14:Minutes,31:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,37.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,30.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,10:Seconds',
#   'Longest song name': "The Afternoon's Hat",
#   'Shortest song time': '0:Hours,3:Minutes,18:Seconds',
#   'Shortest song name': 'Joining the Dots',
#   'Total cost of songs': 5.16,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': "The Afternoon's Hat",
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': "The Afternoon's Hat",
#   'Album name': 'My Propeller - EP',
#   'Release date album': '2010-03-22T07:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,3:Minutes,3:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,3.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,3:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,3:Seconds',
#   'Longest song name': "Don't Sit Down 'Cause I've Moved Your Chair",
#   'Shortest song time': '0:Hours,3:Minutes,3:Seconds',
#   'Shortest song name': "Don't Sit Down 'Cause I've Moved Your Chair",
#   'Total cost of songs': 0.99,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': "Don't Sit Down 'Cause I've Moved Your Chair",
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': "Don't Sit Down 'Cause I've Moved Your Chair",
#   'Album name': "Don't Sit Down 'Cause I've Moved Your Chair - Single",
#   'Release date album': '2011-04-12T12:00:00Z'},
#  {'Count of tracks': 11,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,37:Minutes,5:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,22.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,23:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,16:Seconds',
#   'Longest song name': "That's Where You're Wrong",
#   'Shortest song time': '0:Hours,2:Minutes,22:Seconds',
#   'Shortest song name': 'Library Pictures',
#   'Total cost of songs': 14.189999999999998,
#   'Average cost of songs': 1.2899999999999998,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Reckless Serenade',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Reckless Serenade',
#   'Album name': 'Suck It and See',
#   'Release date album': '2011-06-01T12:00:00Z'},
#  {'Count of tracks': 3,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,8:Minutes,16:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,45.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,3:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,24:Seconds',
#   'Longest song name': 'The Blond-O-Sonic Shimmer Trap',
#   'Shortest song time': '0:Hours,1:Minutes,48:Seconds',
#   'Shortest song name': 'I.D.S.T.',
#   'Total cost of songs': 2.9699999999999998,
#   'Average cost of songs': 0.9899999999999999,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'I.D.S.T.',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'I.D.S.T.',
#   'Album name': "Don't Sit Down 'Cause I've Moved Your Chair - Single",
#   'Release date album': '2011-04-12T12:00:00Z'},
#  {'Count of tracks': 6,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,20:Minutes,33:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,25.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,8.0:Seconds',
#   'Longest song time': '0:Hours,5:Minutes,1:Seconds',
#   'Longest song name': '505',
#   'Shortest song time': '0:Hours,2:Minutes,47:Seconds',
#   'Shortest song name': 'The Hellcat Spangled Shalalala',
#   'Total cost of songs': 5.94,
#   'Average cost of songs': 0.9900000000000001,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': '505',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': '505',
#   'Album name': 'iTunes Festival: London 2011 - EP',
#   'Release date album': '2011-07-08T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,3:Minutes,0:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,0.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,0:Seconds',
#   'Longest song name': 'The Hellcat Spangled Shalalala',
#   'Shortest song time': '0:Hours,3:Minutes,0:Seconds',
#   'Shortest song name': 'The Hellcat Spangled Shalalala',
#   'Total cost of songs': 0.99,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'The Hellcat Spangled Shalalala',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'The Hellcat Spangled Shalalala',
#   'Album name': 'The Hellcat Spangled Shalalala - Single',
#   'Release date album': '2011-06-01T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,7:Minutes,3:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,31.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,31.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,45:Seconds',
#   'Longest song name': 'Suck It and See',
#   'Shortest song time': '0:Hours,3:Minutes,17:Seconds',
#   'Shortest song name': 'Evil Twin',
#   'Total cost of songs': 1.98,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Evil Twin',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Evil Twin',
#   'Album name': 'Suck It and See - Single',
#   'Release date album': '2011-10-31T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,3:Minutes,37:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,37.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,37:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,37:Seconds',
#   'Longest song name': 'Black Treacle',
#   'Shortest song time': '0:Hours,3:Minutes,37:Seconds',
#   'Shortest song name': 'Black Treacle',
#   'Total cost of songs': 0.99,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Black Treacle',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Black Treacle',
#   'Album name': 'Black Treacle - Single',
#   'Release date album': '2011-06-01T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,3:Minutes,20:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,20.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,20:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,20:Seconds',
#   'Longest song name': 'R U Mine?',
#   'Shortest song time': '0:Hours,3:Minutes,20:Seconds',
#   'Shortest song name': 'R U Mine?',
#   'Total cost of songs': 1.29,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'R U Mine?',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'R U Mine?',
#   'Album name': 'R U Mine? - Single',
#   'Release date album': '2012-02-28T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,6:Minutes,21:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,10.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,10.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,20:Seconds',
#   'Longest song name': 'R U Mine?',
#   'Shortest song time': '0:Hours,3:Minutes,1:Seconds',
#   'Shortest song name': 'Electricity',
#   'Total cost of songs': 2.58,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Electricity',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Electricity',
#   'Album name': 'R U Mine? / Electricity - Single',
#   'Release date album': '2012-02-27T12:00:00Z'},
#  {'Count of tracks': 12,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,41:Minutes,45:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,28.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,23.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,31:Seconds',
#   'Longest song name': 'Do I Wanna Know?',
#   'Shortest song time': '0:Hours,2:Minutes,41:Seconds',
#   'Shortest song name': "Why'd You Only Call Me When You're High?",
#   'Total cost of songs': 15.479999999999997,
#   'Average cost of songs': 1.2899999999999998,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Do I Wanna Know?',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Do I Wanna Know?',
#   'Album name': 'AM',
#   'Release date album': '2013-06-19T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,7:Minutes,0:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,30.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,30.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,33:Seconds',
#   'Longest song name': 'Do I Wanna Know?',
#   'Shortest song time': '0:Hours,2:Minutes,26:Seconds',
#   'Shortest song name': '2013',
#   'Total cost of songs': 2.58,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Do I Wanna Know?',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Do I Wanna Know?',
#   'Album name': 'Do I Wanna Know? - Single',
#   'Release date album': '2013-06-19T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,5:Minutes,49:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,54.0:Seconds',
#   'Median track time': '0.0:Hours,2.0:Minutes,54.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,8:Seconds',
#   'Longest song name': 'Stop the World I Wanna Get Off With You',
#   'Shortest song time': '0:Hours,2:Minutes,41:Seconds',
#   'Shortest song name': "Why'd You Only Call Me When You're High?",
#   'Total cost of songs': 2.58,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Stop the World I Wanna Get Off With You',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Stop the World I Wanna Get Off With You',
#   'Album name': "Why'd You Only Call Me When You're High? - Single",
#   'Release date album': '2013-08-11T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,6:Minutes,28:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,14.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,14.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,26:Seconds',
#   'Longest song name': 'One For the Road',
#   'Shortest song time': '0:Hours,3:Minutes,2:Seconds',
#   'Shortest song name': "You're So Dark",
#   'Total cost of songs': 2.58,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': "You're So Dark",
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': "You're So Dark",
#   'Album name': 'One For the Road - Single',
#   'Release date album': '2013-12-09T12:00:00Z'},
#  {'Count of tracks': 17,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,59:Minutes,33:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,30.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,26:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,32:Seconds',
#   'Longest song name': 'Do I Wanna Know?',
#   'Shortest song time': '0:Hours,2:Minutes,41:Seconds',
#   'Shortest song name': "Why'd You Only Call Me When You're High?",
#   'Total cost of songs': 21.929999999999993,
#   'Average cost of songs': 1.2899999999999996,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Do I Wanna Know?',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Do I Wanna Know?',
#   'Album name': 'AM (Live EP Bonus Edition)',
#   'Release date album': '2013-06-19T12:00:00Z'},
#  {'Count of tracks': 5,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,17:Minutes,46:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,33.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,27:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,27:Seconds',
#   'Longest song name': 'Do I Wanna Know?',
#   'Shortest song time': '0:Hours,2:Minutes,59:Seconds',
#   'Shortest song name': 'Fireside',
#   'Total cost of songs': 6.45,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Do I Wanna Know?',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Do I Wanna Know?',
#   'Album name': 'iTunes Festival: London 2013 - EP',
#   'Release date album': '2013-12-16T08:00:00Z'},
#  {'Count of tracks': 11,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,40:Minutes,57:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,43.0:Seconds',
#   'Median track time': '0:Hours,3:Minutes,28:Seconds',
#   'Longest song time': '0:Hours,5:Minutes,54:Seconds',
#   'Longest song name': 'Star Treatment',
#   'Shortest song time': '0:Hours,2:Minutes,38:Seconds',
#   'Shortest song name': 'American Sports',
#   'Total cost of songs': 14.189999999999998,
#   'Average cost of songs': 1.2899999999999998,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': "The World's First Ever Monster Truck Front Flip",
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': "The World's First Ever Monster Truck Front Flip",
#   'Album name': 'Tranquility Base Hotel & Casino',
#   'Release date album': '2018-05-11T12:00:00Z'},
#  {'Count of tracks': 2,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,7:Minutes,13:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,36.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,36.0:Seconds',
#   'Longest song time': '0:Hours,3:Minutes,41:Seconds',
#   'Longest song name': 'Anyways',
#   'Shortest song time': '0:Hours,3:Minutes,31:Seconds',
#   'Shortest song name': 'Tranquility Base Hotel & Casino',
#   'Total cost of songs': 2.58,
#   'Average cost of songs': 1.29,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Anyways',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Anyways',
#   'Album name': 'Tranquility Base Hotel & Casino - Single',
#   'Release date album': '2018-11-30T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'música tropical',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,2:Minutes,28:Seconds',
#   'Average track time': '0.0:Hours,2.0:Minutes,28.0:Seconds',
#   'Median track time': '0:Hours,2:Minutes,28:Seconds',
#   'Longest song time': '0:Hours,2:Minutes,28:Seconds',
#   'Longest song name': 'Dancing Shoes',
#   'Shortest song time': '0:Hours,2:Minutes,28:Seconds',
#   'Shortest song name': 'Dancing Shoes',
#   'Total cost of songs': 0.99,
#   'Average cost of songs': 0.99,
#   'Median cost of songs': 0.99,
#   'Most expensive song cost': 0.99,
#   'Most expensive song name': 'Dancing Shoes',
#   'Сheapest song cost': 0.99,
#   'Сheapest song name': 'Dancing Shoes',
#   'Album name': 'Rhythms del Mundo Cuba',
#   'Release date album': '2006-11-14T12:00:00Z'},
#  {'Count of tracks': 1,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,4:Minutes,33:Seconds',
#   'Average track time': '0.0:Hours,4.0:Minutes,33.0:Seconds',
#   'Median track time': '0:Hours,4:Minutes,33:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,33:Seconds',
#   'Longest song name': 'Do I Wanna Know?',
#   'Shortest song time': '0:Hours,4:Minutes,33:Seconds',
#   'Shortest song name': 'Do I Wanna Know?',
#   'Total cost of songs': -1.0,
#   'Average cost of songs': -1.0,
#   'Median cost of songs': -1.0,
#   'Most expensive song cost': -1.0,
#   'Most expensive song name': 'Do I Wanna Know?',
#   'Сheapest song cost': -1.0,
#   'Сheapest song name': 'Do I Wanna Know?',
#   'Album name': 'Peaky Blinders (Original Music From The TV Series)',
#   'Release date album': '2013-06-19T12:00:00Z'},
#  {'Count of tracks': 20,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '1:Hours,26:Minutes,18:Seconds',
#   'Average track time': '0.0:Hours,4.0:Minutes,18.0:Seconds',
#   'Median track time': '0.0:Hours,4.0:Minutes,2.0:Seconds',
#   'Longest song time': '0:Hours,6:Minutes,11:Seconds',
#   'Longest song name': 'R U Mine?',
#   'Shortest song time': '0:Hours,3:Minutes,3:Seconds',
#   'Shortest song name': "Why'd You Only Call Me When You're High?",
#   'Total cost of songs': 25.79999999999999,
#   'Average cost of songs': 1.2899999999999996,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': '505',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': '505',
#   'Album name': 'Live at the Royal Albert Hall',
#   'Release date album': '2020-12-04T12:00:00Z'},
#  {'Count of tracks': 10,
#   'Most popular genre': 'alternative',
#   'Count of collection': 1,
#   'Total track time': '0:Hours,37:Minutes,23:Seconds',
#   'Average track time': '0.0:Hours,3.0:Minutes,44.0:Seconds',
#   'Median track time': '0.0:Hours,3.0:Minutes,43.0:Seconds',
#   'Longest song time': '0:Hours,4:Minutes,50:Seconds',
#   'Longest song name': 'Body Paint',
#   'Shortest song time': '0:Hours,2:Minutes,47:Seconds',
#   'Shortest song name': 'Perfect Sense',
#   'Total cost of songs': 12.899999999999999,
#   'Average cost of songs': 1.2899999999999998,
#   'Median cost of songs': 1.29,
#   'Most expensive song cost': 1.29,
#   'Most expensive song name': 'Jet Skis On The Moat',
#   'Сheapest song cost': 1.29,
#   'Сheapest song name': 'Jet Skis On The Moat',
#   'Album name': 'The Car',
#   'Release date album': '2022-10-21T12:00:00Z'}]
